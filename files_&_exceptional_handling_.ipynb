# %% [markdown]
# #Files, exceptional handling, logging and memory management Questions

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# - Interpreted languages execute code line by line, while compiled languages convert the entire code before execution.

# %% [markdown]
# 2. What is exception handling in Python?
#
# - Exception handling is a way to handle runtime errors so the program does not crash.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
#
# - The finally block always executes and is used for cleanup tasks.

# %% [markdown]
# 4. What is logging in Python?
#
# - Logging is used to record program events and errors for debugging and monitoring.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python?
#
# - The __del__ method is called when an object is destroyed to release resources.

# %% [markdown]
# 6. What is the difference between import and from ... import in Python?
#
# - import imports the full module, while from ... import imports specific items.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?
#
# - Multiple exceptions can be handled using multiple except blocks or a tuple of exceptions.

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python?
#
# - The with statement ensures the file is automatically closed after use.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?
#
# - Multithreading uses multiple threads, while multiprocessing uses multiple processes.

# %% [markdown]
# 10. What are the advantages of using logging in a program?
#
# - Logging helps in debugging, error tracking, and system monitoring.

# %% [markdown]
# 11. What is memory management in Python?
#
# - Memory management handles the allocation and deallocation of memory automatically.

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python?
#
# - The steps are try, except, else, and finally.

# %% [markdown]
# 13. Why is memory management important in Python?
#
# - It prevents memory leaks and ensures efficient program execution.

# %% [markdown]
# 14. What is the role of try and except in exception handling?
#
# - try tests risky code, and except handles errors if they occur.

# %% [markdown]
# 15. How does Python's garbage collection system work?
#
# - It automatically removes unused objects to free memory.

# %% [markdown]
# 16. What is the purpose of the else block in exception handling?
#
# - The else block runs when no exception occurs.

# %% [markdown]
# 17. What are the common logging levels in Python?
#
# - Common logging levels are DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# - os.fork() creates a child process manually, while multiprocessing provides a high-level API.

# %% [markdown]
# 19. What is the importance of closing a file in Python?
#
# - Closing a file frees resources and prevents data loss.

# %% [markdown]
# 20. What is the difference between file.read() and file.readline()?
#
# - file.read() reads the entire file, while file.readline() reads one line at a time.

# %% [markdown]
# 21. What is the logging module in Python used for?
#
# - It provides tools to log messages and errors.

# %% [markdown]
# 22. What is the os module in Python used for in file handling?
#
# - The os module is used to interact with the operating system, such as file paths.

# %% [markdown]
# 23. What are the challenges associated with memory management in Python?
#
# - Challenges include high memory usage and garbage collection delays.

# %% [markdown]
# 24. How do you raise an exception manually in Python?
#
# - You can raise an exception using the raise keyword.

# %% [markdown]
# 25. Why is it important to use multithreading in certain applications?
#
# - Multithreading improves performance and responsiveness in I/O-based tasks.

# %% [markdown]
# #Practical Questions

# %%
#1.How can you open a file for writing and write a string to it?

file = open("example.txt", "w")
file.write("Hello, world!")
file.close()

# %%
#2.Write a Python program to read the contents of a file and print each line.

#Read a file and print each line.

file = open("example.txt", "r")
for line in file:
    print(line)
file.close()
# Out:
# Hello, world!

# %%
#3.How would you handle a case where the file doesn't exist while trying to open it for reading.

#Handle file not found while reading.

try:
    file = open("sikku.txt", "r")
    for line in file:
        print(line)
    file.close()
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
#4.Write a Python script that reads from one file and writes its content to another file.

#Read from one file and write to another.

file1 = open("example.txt", "r")
file2 = open("output.txt", "w")
for line in file1:
    file2.write(line)
file1.close()
file2.close()

# %%
#5.How would you catch and handle division by zero error in Python

#Catch division by zero error.

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %%
#6.Write a Python program that logs an error message to a log file when a division by zero exception occurs

#Log error on division by zero.

import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Cannot divide by zero.")
# Out:
# ERROR:root:Cannot divide by zero.

# %%
#7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
#Log INFO, WARNING, and ERROR.

import logging

logging.basicConfig(level=logging.INFO)
logging.info("Info message")
logging.warning("Warning message")
logging.error("Error message")
# Out:
# WARNING:root:Warning message
# ERROR:root:Error message

# %%
#8.Write a program to handle a file opening error using exception handling.

#Handle file opening error.

try:
    file = open("ex.txt", "r")
    for line in file:
        print(line)
    file.close()
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
#9.How can you read a file line by line and store its content in a list in Python.

#Read file line by line into a list

with open("example.txt", "r") as line:
    lines = line.readlines()

# %%
#10.How can you append data to an existing file in Python.

#append data to into data file

with open("example.txt", "a") as file:
    file.write("\nNew line")

# %%
#11.Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

#handlle  missing  disctionary keys

my_dict = {"a": 1, "b": 2}

try:
    value = my_dict["c"]
except KeyError:
    print("Key not found in dictionary.")
# Out:
# Key not found in dictionary.

# %%
#12.Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist

#multiple except block

try:
    x = int("abc")
except ValueError:
    print("Value error")
except ZeroDivisionError:
    print("Zero division error")
# Out:
# Value error

# %%
#13.How would you check if a file exists before attempting to read it in Python.

#Check if file exiting reading

import os

if os.path.exists("example.txt"):
    print("File exists")
# Out:
# File exists

# %%
#14.Write a program that uses the logging module to log both informational and error messages

#Log info and error messege

import logging

logging.basicConfig(filename="app.log", level=logging.INFO)
logging.info("Program started")
logging.error("An error occurred")
# Out:
# ERROR:root:An error occurred

# %%
#15.Write a Python program that prints the content of a file and handles the case when the file is empty.

#print file content and empty file

with open("example.txt", "r") as file:
    content = file.read()
    if content:
        print(content)
    else:
        print("File is empty")
# Out:
# Hello, world!
# New line

# %%
#16.Demonstrate how to use memory profiling to check the memory usage of a small program.

#Memory profiling Example

import tracemalloc

tracemalloc.start()
x = [i for i in range(1000)]
print(tracemalloc.get_traced_memory())
tracemalloc.stop()
# Out:
# (33560, 52159)

# %%
#17.Write a Python program to create and write a list of numbers to a file, one number per line.

#Write list of number to a file

numbers = [1, 2, 3, 4, 5,"Sikku"]

with open("example.txt", "w") as file:
    for n in numbers:
        file.write(str(n) + "\n")
        print(str)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
#18.How would you implement a basic logging setup that logs to a file with rotation after 1MB.

#logging with the rotation after 1MB

import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("app.log", maxBytes=1000000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO)
logging.info("Logging started")

# %%
#19.Write a program that handles both IndexError and KeyError using a try-except block.

#handle both IndexError and keyerror

data = {"a": 1}
lst = [1, 2]

try:
    print(lst[5])
    print(data["b"])
except IndexError:
    print("Index error")
except KeyError:
    print("Key error")
# Out:
# Index error

# %%
#How would you open a file and read its contents using a context manager in Python

#read file using content manager

with open("example.txt", "r") as file:
    print(file.read())
# Out:
# 1
# 2
# 3
# 4
# 5
# Sikku

# %%
#Write a Python program that reads a file and prints the number of occurrences of a specific word.

#Count occurrence of a word in a file

with open("example.txt", "r") as file:
    text = file.read()
    print(text.count("1"))
# Out:
# 1

# %%
#How can you check if a file is empty before attempting to read its contents.

#checks if file is empty

import os

if os.path.getsize("example.txt") == 0:
    print("File is empty")

# %%
#Write a Python program that writes to a log file when an error occurs during file handling.

#. Log error during file handling.
import logging

logging.basicConfig(filename="file_error.log", level=logging.ERROR)

try:
    open("missing.txt", "r")
except FileNotFoundError:
    logging.error("File not found error")
# Out:
# ERROR:root:File not found error
